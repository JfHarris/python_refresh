# %%
# pylint overview notes

# running pylint whatever.py will not give metrics under "Report" section below

# pylint myexample.py -r y
# running pylint linter on simple_1.py with command above

# OUTPUT
# ************* Module simple_1
# simple_1.py:1:0: C0114: Missing module docstring (missing-module-docstring) --- STYLE
# simple_1.py:3:0: C0103: Constant name "a" doesn't conform to UPPER_CASE naming style (invalid-name) --- STYLE
# simple_1.py:4:0: C0103: Constant name "b" doesn't conform to UPPER_CASE naming style (invalid-name) --- STYLE
# simple_1.py:7:6: E0602: Undefined variable 'B' (undefined-variable) --- ACTUAL ERROR, note the E


# Report
# ======
# 4 statements analysed.

# Statistics by type
# ------------------

# +---------+-------+-----------+-----------+------------+---------+
# |type     |number |old number |difference |%documented |%badname |
# +=========+=======+===========+===========+============+=========+
# |module   |1      |1          |=          |0.00        |0.00     |
# +---------+-------+-----------+-----------+------------+---------+
# |class    |0      |NC         |NC         |0           |0        |
# +---------+-------+-----------+-----------+------------+---------+
# |method   |0      |NC         |NC         |0           |0        |
# +---------+-------+-----------+-----------+------------+---------+
# |function |0      |NC         |NC         |0           |0        |
# +---------+-------+-----------+-----------+------------+---------+



# 9 lines have been analyzed

# Raw metrics
# -----------

# +----------+-------+------+---------+-----------+
# |type      |number |%     |previous |difference |
# +==========+=======+======+=========+===========+
# |code      |5      |55.56 |NC       |NC         |
# +----------+-------+------+---------+-----------+
# |docstring |0      |0.00  |NC       |NC         |
# +----------+-------+------+---------+-----------+
# |comment   |1      |11.11 |NC       |NC         |
# +----------+-------+------+---------+-----------+
# |empty     |3      |33.33 |NC       |NC         |
# +----------+-------+------+---------+-----------+



# Duplication
# -----------

# +-------------------------+------+---------+-----------+
# |                         |now   |previous |difference |
# +=========================+======+=========+===========+
# |nb duplicated lines      |0     |0        |0          |
# +-------------------------+------+---------+-----------+
# |percent duplicated lines |0.000 |0.000    |=          |
# +-------------------------+------+---------+-----------+



# Messages by category
# --------------------

# +-----------+-------+---------+-----------+
# |type       |number |previous |difference |
# +===========+=======+=========+===========+
# |convention |3      |3        |3          |
# +-----------+-------+---------+-----------+
# |refactor   |0      |0        |0          |
# +-----------+-------+---------+-----------+
# |warning    |0      |0        |0          |
# +-----------+-------+---------+-----------+
# |error      |1      |1        |1          |
# +-----------+-------+---------+-----------+



# Messages
# --------

# +-------------------------+------------+
# |message id               |occurrences |
# +=========================+============+
# |invalid-name             |2           |
# +-------------------------+------------+
# |undefined-variable       |1           |
# +-------------------------+------------+
# |missing-module-docstring |1           |
# +-------------------------+------------+

# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 0.00/10, +0.00)

# after fixing style and error, run pylint simple_1.py -r y

#OUTPUT
# Report
# ======
# 6 statements analysed.

# Statistics by type
# ------------------

# +---------+-------+-----------+-----------+------------+---------+
# |type     |number |old number |difference |%documented |%badname |
# +=========+=======+===========+===========+============+=========+
# |module   |1      |1          |=          |100.00      |0.00     |
# +---------+-------+-----------+-----------+------------+---------+
# |class    |0      |NC         |NC         |0           |0        |
# +---------+-------+-----------+-----------+------------+---------+
# |method   |0      |NC         |NC         |0           |0        |
# +---------+-------+-----------+-----------+------------+---------+
# |function |1      |NC         |NC         |100.00      |0.00     |
# +---------+-------+-----------+-----------+------------+---------+



# 27 lines have been analyzed

# Raw metrics
# -----------

# +----------+-------+------+---------+-----------+
# |type      |number |%     |previous |difference |
# +==========+=======+======+=========+===========+
# |code      |7      |25.93 |5        |+2.00      |
# +----------+-------+------+---------+-----------+
# |docstring |6      |22.22 |NC       |NC         |
# +----------+-------+------+---------+-----------+
# |comment   |5      |18.52 |1        |+4.00      |
# +----------+-------+------+---------+-----------+
# |empty     |9      |33.33 |3        |+6.00      |
# +----------+-------+------+---------+-----------+



# Duplication
# -----------

# +-------------------------+------+---------+-----------+
# |                         |now   |previous |difference |
# +=========================+======+=========+===========+
# |nb duplicated lines      |0     |0        |0          |
# +-------------------------+------+---------+-----------+
# |percent duplicated lines |0.000 |0.000    |=          |
# +-------------------------+------+---------+-----------+



# Messages by category
# --------------------

# +-----------+-------+---------+-----------+
# |type       |number |previous |difference |
# +===========+=======+=========+===========+
# |convention |0      |3        |3          |
# +-----------+-------+---------+-----------+
# |refactor   |0      |0        |0          |
# +-----------+-------+---------+-----------+
# |warning    |0      |0        |0          |
# +-----------+-------+---------+-----------+
# |error      |0      |1        |1          |
# +-----------+-------+---------+-----------+



# Messages
# --------

# +-----------+------------+
# |message id |occurrences |
# +===========+============+




# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 0.00/10, +10.00)
